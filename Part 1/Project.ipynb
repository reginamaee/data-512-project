# %% [markdown]
# # Common Analysis
# ### How did masking policies change the progression of confirmed COVID-19 cases from February 1, 2020 through October 1, 2021?

# %% [markdown]
# We will be using various datasets to conduct this analysis. The first dataset is from John Hopkins University data and is the RAW number of U.S. confirmed cases. This provides the number of new confirmed COVID-19 cases daily. The next dataset is the CDC dataset of masking mandates by country and the NY times mask compliance survey data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw_cases = pd.read_csv("RAW_us_confirmed_cases.csv")
mask_mandates = pd.read_csv("U.S._State_and_Territorial_Public_Mask_Mandates_From_April_10__2020_through_August_15__2021_by_County_by_Day.csv")
mask_use = pd.read_csv("mask-use-by-county.csv")

# %% [markdown]
# We will conduct analysis on King County, Washington only.
# ### Data Extraction & Cleaning: Johns Hopkins Confirmed Cases

# %%
kc_raw_cases = raw_cases[(raw_cases["Province_State"] == "Washington") & (raw_cases["Admin2"] == "King")]
kc_raw_cases.head()
# Out:
#      Province_State Admin2       UID iso2 iso3  code3     FIPS Country_Region  \
# 3161     Washington   King  84053033   US  USA    840  53033.0             US
#
#             Lat       Long_  ... 10/22/22  10/23/22  10/24/22  10/25/22  \
# 3161  47.491379 -121.834613  ...   522154    522154    522610    522610
#
#       10/26/22  10/27/22  10/28/22  10/29/22  10/30/22  10/31/22
# 3161    522968    522968    522968    522968    522968    523885
#
# [1 rows x 1025 columns]

# %%
# change dataset from wide to long
kc_raw_cases = pd.melt(kc_raw_cases, id_vars=['Province_State', 'Admin2', 'UID', 'iso2', 'iso3', 'code3', 'FIPS','Country_Region', 'Lat', 'Long_', 'Combined_Key'])
kc_raw_cases = kc_raw_cases.rename(columns={"variable":"date", "value": "cases"})

# %%
# change date variable to date format
kc_raw_cases['new_date_format'] = pd.to_datetime(kc_raw_cases['date'])

# sort the values by date
kc_raw_cases = kc_raw_cases.sort_values(by=['new_date_format'])
kc_raw_cases['daily_cases'] = kc_raw_cases['cases'].diff()

# %% [markdown]
# Because we expect the reported cases to be a cumulative count daily (as in the reported case for one day will be the sum of the reported cases from the previous day and the reported cases on that day), we should not see any case values that are less than the previous date. However, there does lie some discrepency in the data that do report this issue. We find this by finding any negative computed values from the 'daily_cases' column.

# %%
daily_cases_less_than_one = kc_raw_cases[kc_raw_cases['daily_cases'] < 0]
daily_cases_less_than_one
# Out:
#     Province_State Admin2       UID iso2 iso3  code3     FIPS Country_Region  \
# 56      Washington   King  84053033   US  USA    840  53033.0             US
# 502     Washington   King  84053033   US  USA    840  53033.0             US
# 833     Washington   King  84053033   US  USA    840  53033.0             US
#
#            Lat       Long_          Combined_Key     date   cases  \
# 56   47.491379 -121.834613  King, Washington, US  3/18/20     562
# 502  47.491379 -121.834613  King, Washington, US   6/7/21  109349
# 833  47.491379 -121.834613  King, Washington, US   5/4/22  399865
#
#     new_date_format  daily_cases
# 56       2020-03-18         -7.0
# 502      2021-06-07       -871.0
# 833      2022-05-04       -423.0

# %% [markdown]
# We see three different instances where the daily cases are negative. This might be due to some typos in inputting data or some circumstance where they over reported on the previous dates. To correct this, we will linear interpolate the values for these dates (and possibly maybe for some related dates around it)

# %%
# create interpolation function (obtained online)
def interpolate(d, x):
    calculate = d[0][1] + (x - d[0][0]) * ((d[1][1] - d[0][1])/(d[1][0] - d[0][0]))
    return calculate

# %%
# looking at the first instance occuring on 3/18/2020
# we will grab a few dates before and after
first_instance = kc_raw_cases[(kc_raw_cases['new_date_format'] >= "2020-03-15") & (kc_raw_cases['new_date_format'] <= "2020-03-21")]
first_instance
# Out:
#    Province_State Admin2       UID iso2 iso3  code3     FIPS Country_Region  \
# 53     Washington   King  84053033   US  USA    840  53033.0             US
# 54     Washington   King  84053033   US  USA    840  53033.0             US
# 55     Washington   King  84053033   US  USA    840  53033.0             US
# 56     Washington   King  84053033   US  USA    840  53033.0             US
# 57     Washington   King  84053033   US  USA    840  53033.0             US
# 58     Washington   King  84053033   US  USA    840  53033.0             US
# 59     Washington   King  84053033   US  USA    840  53033.0             US
#
#           Lat       Long_          Combined_Key     date  cases  \
# 53  47.491379 -121.834613  King, Washington, US  3/15/20    387
# 54  47.491379 -121.834613  King, Washington, US  3/16/20    488
# 55  47.491379 -121.834613  King, Washington, US  3/17/20    569
# 56  47.491379 -121.834613  King, Washington, US  3/18/20    562
# 57  47.491379 -121.834613  King, Washington, US  3/19/20    693
# 58  47.491379 -121.834613  King, Washington, US  3/20/20    793
# 59  47.491379 -121.834613  King, Washington, US  3/21/20    934
#
#    new_date_format  daily_cases
# 53      2020-03-15          0.0
# 54      2020-03-16        101.0
# 55      2020-03-17         81.0
# 56      2020-03-18         -7.0
# 57      2020-03-19        131.0
# 58      2020-03-20        100.0
# 59      2020-03-21        141.0

# %% [markdown]
# Looking more in depth at the first date, we see the cumulative cases follow the same pattern with the expection of the reported cases on 3/18/2020, thus we will linear interpolate this case value. (using the value from 3/17/2020 and 3/19/2020)

# %%
# the difference between the dates are one so we set dummy y values
# 3/17/2020 = 1
# 3/18/2020 = 2
# 3/19/2020 = 3
case_vals = [[1, 569], [3,693]]
date_inter = 2

new_num_cases_3_18 = interpolate(case_vals, date_inter)
new_num_cases_3_18
# Out:
# 631.0

# %% [markdown]
# Next, we will do the same procedure and look at the next date presenting this issue.

# %%
# looking at the second instance occuring on 6/7/2021
# we will grab a few dates before and after
second_instance = kc_raw_cases[(kc_raw_cases['new_date_format'] >= "2021-06-04") & (kc_raw_cases['new_date_format'] <= "2021-06-11")]
second_instance
# Out:
#     Province_State Admin2       UID iso2 iso3  code3     FIPS Country_Region  \
# 499     Washington   King  84053033   US  USA    840  53033.0             US
# 500     Washington   King  84053033   US  USA    840  53033.0             US
# 501     Washington   King  84053033   US  USA    840  53033.0             US
# 502     Washington   King  84053033   US  USA    840  53033.0             US
# 503     Washington   King  84053033   US  USA    840  53033.0             US
# 504     Washington   King  84053033   US  USA    840  53033.0             US
# 505     Washington   King  84053033   US  USA    840  53033.0             US
# 506     Washington   King  84053033   US  USA    840  53033.0             US
#
#            Lat       Long_          Combined_Key     date   cases  \
# 499  47.491379 -121.834613  King, Washington, US   6/4/21  110089
# 500  47.491379 -121.834613  King, Washington, US   6/5/21  110220
# 501  47.491379 -121.834613  King, Washington, US   6/6/21  110220
# 502  47.491379 -121.834613  King, Washington, US   6/7/21  109349
# 503  47.491379 -121.834613  King, Washington, US   6/8/21  109458
# 504  47.491379 -121.834613  King, Washington, US   6/9/21  110688
# 505  47.491379 -121.834613  King, Washington, US  6/10/21  110799
# 506  47.491379 -121.834613  King, Washington, US  6/11/21  110911
#
#     new_date_format  daily_cases
# 499      2021-06-04        123.0
# 500      2021-06-05        131.0
# 501      2021-06-06          0.0
# 502      2021-06-07       -871.0
# 503      2021-06-08        109.0
# 504      2021-06-09       1230.0
# 505      2021-06-10        111.0
# 506      2021-06-11        112.0

# %% [markdown]
# In the table above, we can decide to interpolate for the dates: 6/7/2021 and 6/8/2021.

# %%
# the difference between the dates are one, so we set dummy y values
# 6/6/2021 = 1
# 6/7/2021 = 2
# 6/8/2021 = 3
# 6/9/2021 = 4
case_vals = [[1, 110220], [4,110688]]

new_num_cases_6_7 = interpolate(case_vals, 2)
new_num_cases_6_8 = interpolate(case_vals, 3)
print(new_num_cases_6_7)
print(new_num_cases_6_8)
# Out:
# 110376.0
# 110532.0

# %% [markdown]
# Now, we will look at the last instance of negative daily cases.

# %%
# looking at the second instance occuring on 5/4/2022
# we will grab a few dates before and after
third_instance = kc_raw_cases[(kc_raw_cases['new_date_format'] >= "2022-04-28") & (kc_raw_cases['new_date_format'] <= "2022-05-20")]
third_instance
# Out:
#     Province_State Admin2       UID iso2 iso3  code3     FIPS Country_Region  \
# 827     Washington   King  84053033   US  USA    840  53033.0             US
# 828     Washington   King  84053033   US  USA    840  53033.0             US
# 829     Washington   King  84053033   US  USA    840  53033.0             US
# 830     Washington   King  84053033   US  USA    840  53033.0             US
# 831     Washington   King  84053033   US  USA    840  53033.0             US
# 832     Washington   King  84053033   US  USA    840  53033.0             US
# 833     Washington   King  84053033   US  USA    840  53033.0             US
# 834     Washington   King  84053033   US  USA    840  53033.0             US
# 835     Washington   King  84053033   US  USA    840  53033.0             US
# 836     Washington   King  84053033   US  USA    840  53033.0             US
# 837     Washington   King  84053033   US  USA    840  53033.0             US
# 838     Washington   King  84053033   US  USA    840  53033.0             US
# 839     Washington   King  84053033   US  USA    840  53033.0             US
# 840     Washington   King  84053033   US  USA    840  53033.0             US
# 841     Washington   King  84053033   US  USA    840  53033.0             US
# 842     Washington   King  84053033   US  USA    840  53033.0             US
# 843     Washington   King  84053033   US  USA    840  53033.0             US
# 844     Washington   King  84053033   US  USA    840  53033.0             US
# 845     Washington   King  84053033   US  USA    840  53033.0             US
# 846     Washington   King  84053033   US  USA    840  53033.0             US
# 847     Washington   King  84053033   US  USA    840  53033.0             US
# 848     Washington   King  84053033   US  USA    840  53033.0             US
# 849     Washington   King  84053033   US  USA    840  53033.0             US
#
#            Lat       Long_          Combined_Key     date   cases  \
# 827  47.491379 -121.834613  King, Washington, US  4/28/22  393029
# 828  47.491379 -121.834613  King, Washington, US  4/29/22  395160
# 829  47.491379 -121.834613  King, Washington, US  4/30/22  395160
# 830  47.491379 -121.834613  King, Washington, US   5/1/22  395160
# 831  47.491379 -121.834613  King, Washington, US   5/2/22  400288
# 832  47.491379 -121.834613  King, Washington, US   5/3/22  400288
# 833  47.491379 -121.834613  King, Washington, US   5/4/22  399865
# 834  47.491379 -121.834613  King, Washington, US   5/5/22  399865
# 835  47.491379 -121.834613  King, Washington, US   5/6/22  399865
# 836  47.491379 -121.834613  King, Washington, US   5/7/22  399865
# 837  47.491379 -121.834613  King, Washington, US   5/8/22  399865
# 838  47.491379 -121.834613  King, Washington, US   5/9/22  405163
# 839  47.491379 -121.834613  King, Washington, US  5/10/22  405163
# 840  47.491379 -121.834613  King, Washington, US  5/11/22  407136
# 841  47.491379 -121.834613  King, Washington, US  5/12/22  407136
# 842  47.491379 -121.834613  King, Washington, US  5/13/22  409986
# 843  47.491379 -121.834613  King, Washington, US  5/14/22  409986
# 844  47.491379 -121.834613  King, Washington, US  5/15/22  409986
# 845  47.491379 -121.834613  King, Washington, US  5/16/22  413357
# 846  47.491379 -121.834613  King, Washington, US  5/17/22  413357
# 847  47.491379 -121.834613  King, Washington, US  5/18/22  415703
# 848  47.491379 -121.834613  King, Washington, US  5/19/22  415703
# 849  47.491379 -121.834613  King, Washington, US  5/20/22  419201
#
#     new_date_format  daily_cases
# 827      2022-04-28          0.0
# 828      2022-04-29       2131.0
# 829      2022-04-30          0.0
# 830      2022-05-01          0.0
# 831      2022-05-02       5128.0
# 832      2022-05-03          0.0
# 833      2022-05-04       -423.0
# 834      2022-05-05          0.0
# 835      2022-05-06          0.0
# 836      2022-05-07          0.0
# 837      2022-05-08          0.0
# 838      2022-05-09       5298.0
# 839      2022-05-10          0.0
# 840      2022-05-11       1973.0
# 841      2022-05-12          0.0
# 842      2022-05-13       2850.0
# 843      2022-05-14          0.0
# 844      2022-05-15          0.0
# 845      2022-05-16       3371.0
# 846      2022-05-17          0.0
# 847      2022-05-18       2346.0
# 848      2022-05-19          0.0
# 849      2022-05-20       3498.0

# %% [markdown]
# For this instance, we see that the potential typo exists in the date ranges: 5/4/2022 - 5/8/2022. In this case, we will overestimate and interpolate case numbers for these dates.

# %%
# the difference between the dates are one, so we set dummy y values
# 5/3/2022 = 1
# 5/4/2022 = 2
# 5/5/2022 = 3
# 5/6/2022 = 4
# 5/7/2022 = 5
# 5/8/2022 = 6
# 5/9/2022 = 7
case_vals = [[1, 400288], [7,405163]]

new_num_cases_5_4 = interpolate(case_vals, 2)
new_num_cases_5_5 = interpolate(case_vals, 3)
new_num_cases_5_6 = interpolate(case_vals, 4)
new_num_cases_5_7 = interpolate(case_vals, 5)
new_num_cases_5_8 = interpolate(case_vals, 6)

print(new_num_cases_5_4)
print(new_num_cases_5_5)
print(new_num_cases_5_6)
print(new_num_cases_5_7)
print(new_num_cases_5_8)
# Out:
# 401100.5
# 401913.0
# 402725.5
# 403538.0
# 404350.5

# %%
# round case values to be discrete
new_num_cases_5_4 = round(new_num_cases_5_4)
new_num_cases_5_6 = round(new_num_cases_5_6)
new_num_cases_5_8 = round(new_num_cases_5_8)

print(new_num_cases_5_4)
print(new_num_cases_5_5)
print(new_num_cases_5_6)
print(new_num_cases_5_7)
print(new_num_cases_5_8)
# Out:
# 401100
# 401913.0
# 402726
# 403538.0
# 404350

# %% [markdown]
# After interpolating and finding the new case values for each of these dates, we will replace them in the dataframe and recompute the daily number of cases.

# %%
kc_fixed_cases = kc_raw_cases

# %%
kc_fixed_cases.loc[kc_fixed_cases["date"] == "3/18/20", "cases"] = new_num_cases_3_18
kc_fixed_cases.loc[kc_fixed_cases["date"] == "6/7/21", "cases"] = new_num_cases_6_7
kc_fixed_cases.loc[kc_fixed_cases["date"] == "6/8/21", "cases"] = new_num_cases_6_8
kc_fixed_cases.loc[kc_fixed_cases["date"] == "5/4/22", "cases"] = new_num_cases_5_4
kc_fixed_cases.loc[kc_fixed_cases["date"] == "5/5/22", "cases"] = new_num_cases_5_5
kc_fixed_cases.loc[kc_fixed_cases["date"] == "5/6/22", "cases"] = new_num_cases_5_6
kc_fixed_cases.loc[kc_fixed_cases["date"] == "5/7/22", "cases"] = new_num_cases_5_7
kc_fixed_cases.loc[kc_fixed_cases["date"] == "5/8/22", "cases"] = new_num_cases_5_8

# %%
kc_fixed_cases.loc['daily_cases'] = kc_fixed_cases['cases'].diff()
kc_fixed_cases['daily_cases'].iloc[0] = kc_fixed_cases['cases'].iloc[0]
# double check: are there any values less than 0/negative?
print(min(kc_fixed_cases['daily_cases'].values))
# Out:
# -871.0
# C:\Users\rmvdo\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
kc_fixed_cases.to_csv("KC_fixed_cases.csv")

# %% [markdown]
# ### Data Extraction & Cleaning: Mask Mandates

# %%
# subset to only King County, WA
kc_mask_mandates = mask_mandates[(mask_mandates['State_Tribe_Territory'] == "WA") & (mask_mandates['County_Name'] == "King County")]

# %%
# change date object to be in datetime format
kc_mask_mandates['new_date_format'] = pd.to_datetime(kc_mask_mandates['date'])
# order by date
kc_mask_mandates = kc_mask_mandates.sort_values(by=['new_date_format'])
#kc_mask_mandates
# Out:
# <ipython-input-133-679863cb390b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kc_mask_mandates['new_date_format'] = pd.to_datetime(kc_mask_mandates['date'])

# %%
# keep only dates where the mask mandate is required, (there are no breaks in the data)
kc_mask_mandates = kc_mask_mandates[kc_mask_mandates['Face_Masks_Required_in_Public'] == "Yes"]

# %%
# date range of King County Mask Mandate
print("The date range for King County Mask Mandate is: " + str(min(kc_mask_mandates['new_date_format'])) + "-" + str(max(kc_mask_mandates['new_date_format'])))
# Out:
# The date range for King County Mask Mandate is: 2020-06-26 00:00:00-2021-08-15 00:00:00

# %%
kc_mask_mandates
# Out:
#         State_Tribe_Territory  County_Name  FIPS_State  FIPS_County  \
# 789569                     WA  King County          53           33
# 789735                     WA  King County          53           33
# 789756                     WA  King County          53           33
# 789757                     WA  King County          53           33
# 789758                     WA  King County          53           33
# ...                       ...          ...         ...          ...
# 1534257                    WA  King County          53           33
# 1534258                    WA  King County          53           33
# 1534259                    WA  King County          53           33
# 1534260                    WA  King County          53           33
# 1534261                    WA  King County          53           33
#
#               date  order_code Face_Masks_Required_in_Public Source_of_Action  \
# 789569    5/3/2020           2                           NaN              NaN
# 789735    5/4/2020           2                           NaN              NaN
# 789756   4/10/2020           2                           NaN              NaN
# 789757   4/11/2020           2                           NaN              NaN
# 789758   4/12/2020           2                           NaN              NaN
# ...            ...         ...                           ...              ...
# 1534257  8/11/2021           1                           Yes         Official
# 1534258  8/12/2021           1                           Yes         Official
# 1534259  8/13/2021           1                           Yes         Official
# 1534260  8/14/2021           1                           Yes         Official
# 1534261  8/15/2021           1                           Yes         Official
#
#          URL                                           Citation
# 789569   NaN                                                NaN
# 789735   NaN                                                NaN
# 789756   NaN                                                NaN
# 789757   NaN                                                NaN
# 789758   NaN                                                NaN
# ...      ...                                                ...
# 1534257  NaN  Wa. Sec. of Health Order No. 20-03.3 (June 29,...
# 1534258  NaN  Wa. Sec. of Health Order No. 20-03.3 (June 29,...
# 1534259  NaN  Wa. Sec. of Health Order No. 20-03.3 (June 29,...
# 1534260  NaN  Wa. Sec. of Health Order No. 20-03.3 (June 29,...
# 1534261  NaN  Wa. Sec. of Health Order No. 20-03.3 (June 29,...
#
# [493 rows x 10 columns]

# %% [markdown]
# ### Data Extraction & Cleaning: NY Times Mask Survey
# We will obtain the NY times masking survey for King County by matching the FIPS code provided in the John Hopkins dataset file.

# %%
kc_code = kc_raw_cases['FIPS'].iloc[0]

# %%
kc_mask_use = mask_use[mask_use['COUNTYFP'] == kc_code]
kc_mask_use
# Out:
#       COUNTYFP  NEVER  RARELY  SOMETIMES  FREQUENTLY  ALWAYS
# 2969     53033  0.016    0.02       0.05       0.191   0.724

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# Let's start at looking at the progression of daily cases in King County, WA from February 1, 2020 to October 1, 2021.

# %%
# subset data to get these date ranges
kc_cases = kc_fixed_cases[(kc_fixed_cases['new_date_format'] >= "2020-02-01") & (kc_fixed_cases['new_date_format'] <= "2021-10-01")]
kc_cases = kc_cases.reset_index()

# %%
fig, ax1 = plt.subplots(figsize=(20,10))
ax2 = ax1.twinx()
sns.set_style('ticks')
sns.lineplot(x="new_date_format", y="cases", data = kc_cases, ax=ax1, color='red', label='Total Number of Cases')
sns.lineplot(x="new_date_format", y="daily_cases", data = kc_cases, ax=ax2, label='Daily Reported Cases')
plt.axvspan(min(kc_mask_mandates['new_date_format']), max(kc_mask_mandates['new_date_format']), color='green', alpha=0.1, label='Mask Mandate Period')
ax1.set_xlabel('Date')
ax1.set_ylabel('Cumulative Cases')
ax2.set_ylabel('Daily Cases')
plt.legend(fontsize=13)

# %% [markdown]
# We can see the overall trend of daily cases and cumulative cases in King County, WA. What is highly noticeable is the giant spike in daily cases around approximately January 2021. However, there are many errors or uncertainty within these plots. A concern would be looking at the number of cases at the daily level. When looking at the data closely, the bigger spikes seem to come in the beginning of the week which indicates that testing is more prevalent at these times (and is inconsistent overall). Testing doesn't seem to occur on the weekend or major holidays, which can cause a huge value in the number of daily cases. To alleviate that concern, we will look at the differences between cases on a bi-weekly scale.
#
# - Rather than grouping the dates by every 14 days, it is important to ensure we account for weekends and holidays (since this would drive a difference in testing). Meaning we should look at our bi-weekly schedules in the standard manner, starting with a Sunday and ending with a Saturday.

# %%
# set biweekly week groups
# first instance we will set from Saturday 2/1/2020 - 2/15/2020
# the rest will be group starting from a sunday and ending with a saturday
#kc_cases.insert(len(kc_cases.columns), 'Week', np.nan)

for i in range(15):
    kc_cases.at[i, 'Week'] = 1
start = 15
count = 0
week_start = 2
for i in range(15, len(kc_cases)):
    if (count == 14):
        count = 0
        week_start = week_start + 1
    kc_cases.at[i, 'Week'] = week_start
    count = count + 1

# %%
# get biweekly sums
kc_cases_bi_weekly = kc_cases.groupby(['Week'])['daily_cases'].sum().reset_index()
# take cumulative sum
kc_cases_bi_weekly['cases'] = kc_cases_bi_weekly['daily_cases'].cumsum()
# add actual number of cumulative cases from 01/31/2020 (which is just 1)
kc_cases_bi_weekly['cases'] = kc_cases_bi_weekly['cases'] + 1
#kc_cases_bi_weekly['first_date'] = kc_cases.groupby(['Week'])['new_date_format'].min()

# %%
# get dates
dates_temp = kc_cases.groupby(['Week'])['new_date_format'].min().reset_index()
kc_cases_bi_weekly = kc_cases_bi_weekly.merge(dates_temp, on="Week", how="left")

# get weekly averages
avg_temp = kc_cases.groupby(['Week'])['daily_cases'].mean().reset_index()
kc_cases_bi_weekly = kc_cases_bi_weekly.merge(avg_temp, on="Week", how="left")

# %%
kc_cases_bi_weekly = kc_cases_bi_weekly.rename(columns={'daily_cases_x': 'daily_cases', 'daily_cases_y':'average_number_of_cases'})
kc_cases_bi_weekly
# Out:
#     Week  daily_cases     cases new_date_format  average_number_of_cases
# 0    1.0          0.0       1.0      2020-02-01                 0.000000
# 1    2.0          5.0       6.0      2020-02-16                 0.357143
# 2    3.0        381.0     387.0      2020-03-01                27.214286
# 3    4.0       1690.0    2077.0      2020-03-15               120.714286
# 4    5.0       2185.0    4262.0      2020-03-29               156.071429
# 5    6.0       1477.0    5739.0      2020-04-12               105.500000
# 6    7.0       1208.0    6947.0      2020-04-26                86.285714
# 7    8.0        722.0    7669.0      2020-05-10                51.571429
# 8    9.0        812.0    8481.0      2020-05-24                58.000000
# 9   10.0        734.0    9215.0      2020-06-07                52.428571
# 10  11.0       1739.0   10954.0      2020-06-21               124.214286
# 11  12.0       2194.0   13148.0      2020-07-05               156.714286
# 12  13.0       2358.0   15506.0      2020-07-19               168.428571
# 13  14.0       2119.0   17625.0      2020-08-02               151.357143
# 14  15.0       2067.0   19692.0      2020-08-16               147.642857
# 15  16.0       1313.0   21005.0      2020-08-30                93.785714
# 16  17.0       1253.0   22258.0      2020-09-13                89.500000
# 17  18.0       2016.0   24274.0      2020-09-27               144.000000
# 18  19.0       2333.0   26607.0      2020-10-11               166.642857
# 19  20.0       4613.0   31220.0      2020-10-25               329.500000
# 20  21.0       7657.0   38877.0      2020-11-08               546.928571
# 21  22.0       9075.0   47952.0      2020-11-22               648.214286
# 22  23.0       9831.0   57783.0      2020-12-06               702.214286
# 23  24.0       4797.0   62580.0      2020-12-20               342.642857
# 24  25.0       9673.0   72253.0      2021-01-03               690.928571
# 25  26.0       5757.0   78010.0      2021-01-17               411.214286
# 26  27.0       3531.0   81541.0      2021-01-31               252.214286
# 27  28.0       2473.0   84014.0      2021-02-14               176.642857
# 28  29.0       2220.0   86234.0      2021-02-28               158.571429
# 29  30.0       3402.0   89636.0      2021-03-14               243.000000
# 30  31.0       4496.0   94132.0      2021-03-28               321.142857
# 31  32.0       5419.0   99551.0      2021-04-11               387.071429
# 32  33.0       5412.0  104963.0      2021-04-25               386.571429
# 33  34.0       3157.0  108120.0      2021-05-09               225.500000
# 34  35.0       2100.0  110220.0      2021-05-23               150.000000
# 35  36.0       1337.0  111557.0      2021-06-06                95.500000
# 36  37.0       1155.0  112712.0      2021-06-20                82.500000
# 37  38.0       1503.0  114215.0      2021-07-04               107.357143
# 38  39.0       2581.0  116796.0      2021-07-18               184.357143
# 39  40.0       8095.0  124891.0      2021-08-01               578.214286
# 40  41.0       8500.0  133391.0      2021-08-15               607.142857
# 41  42.0       8064.0  141455.0      2021-08-29               576.000000
# 42  43.0       7195.0  148650.0      2021-09-12               513.928571
# 43  44.0       3372.0  152022.0      2021-09-26               562.000000

# %% [markdown]
# Now, we have the cumulative cases and average cases at the bi-weekly level. We will reproduce the previous time series plot to better see the trend of COVID-19 cases in Seattle.

# %%
fig, ax1 = plt.subplots(figsize=(20,10))
ax2 = ax1.twinx()
sns.set_style('ticks')
sns.lineplot(x="new_date_format", y="cases", data = kc_cases, ax=ax1, color='red', label='Total Number of Cases')
sns.lineplot(x="new_date_format", y="daily_cases", data = kc_cases, ax=ax2, label='Daily Reported Cases')
sns.lineplot(x="new_date_format", y="average_number_of_cases", data=kc_cases_bi_weekly, ax=ax2, label="Bi-Weekly Average")
plt.axvspan(min(kc_mask_mandates['new_date_format']), max(kc_mask_mandates['new_date_format']), color='green', alpha=0.1, label='Mask Mandate Period')
ax1.set_xlabel('Date')
ax1.set_ylabel('Cumulative Cases')
ax2.set_ylabel('Daily Cases')
plt.legend(fontsize=13)

# %% [markdown]
# Rate of Change = (old_cases - new_cases)/(time) - time unit will always be 1 (by one day) if looking at daily and 2 for biweekly?

# %%
# plot rate of change
kc_cases['rate_of_change'] = kc_cases['tol'].diff()
kc_cases_bi_weekly['rate_of_change_test'] = kc_cases_bi_weekly['daily_cases'].diff()

# %%
fig, ax1 = plt.subplots(figsize=(10,5))
ax2 = ax1.twinx()
sns.set_style('ticks')
sns.lineplot(x="new_date_format", y="rate_of_change", data = kc_cases_bi_weekly, ax=ax1, color='red', label='Rate of Change')
#sns.lineplot(x="new_date_format", y="daily_cases", data = kc_cases, ax=ax2, label='Daily Reported Cases')
#sns.lineplot(x="new_date_format", y="average_number_of_cases", data=kc_cases_bi_weekly, ax=ax2, label="Bi-Weekly Average")
plt.axvspan(min(kc_mask_mandates['new_date_format']), max(kc_mask_mandates['new_date_format']), color='green', alpha=0.1, label='Mask Mandate Period')
ax1.set_xlabel('Date')
ax1.set_ylabel('Cumulative Cases')
ax2.set_ylabel('Daily Cases')
plt.legend(fontsize=13)

# %% [markdown]
# ### 14 Day Rolling Average to smooth data

# %%
kc_cases['rolling_avg'] = kc_cases.rolling(14, min_periods=1)['daily_cases'].mean()
kc_cases
# Out:
#      index Province_State Admin2         UID iso2 iso3  code3     FIPS  \
# 0       10     Washington   King  84053033.0   US  USA  840.0  53033.0
# 1       11     Washington   King  84053033.0   US  USA  840.0  53033.0
# 2       12     Washington   King  84053033.0   US  USA  840.0  53033.0
# 3       13     Washington   King  84053033.0   US  USA  840.0  53033.0
# 4       14     Washington   King  84053033.0   US  USA  840.0  53033.0
# ..     ...            ...    ...         ...  ...  ...    ...      ...
# 604    614     Washington   King  84053033.0   US  USA  840.0  53033.0
# 605    615     Washington   King  84053033.0   US  USA  840.0  53033.0
# 606    616     Washington   King  84053033.0   US  USA  840.0  53033.0
# 607    617     Washington   King  84053033.0   US  USA  840.0  53033.0
# 608    618     Washington   King  84053033.0   US  USA  840.0  53033.0
#
#     Country_Region        Lat       Long_          Combined_Key     date  \
# 0               US  47.491379 -121.834613  King, Washington, US   2/1/20
# 1               US  47.491379 -121.834613  King, Washington, US   2/2/20
# 2               US  47.491379 -121.834613  King, Washington, US   2/3/20
# 3               US  47.491379 -121.834613  King, Washington, US   2/4/20
# 4               US  47.491379 -121.834613  King, Washington, US   2/5/20
# ..             ...        ...         ...                   ...      ...
# 604             US  47.491379 -121.834613  King, Washington, US  9/27/21
# 605             US  47.491379 -121.834613  King, Washington, US  9/28/21
# 606             US  47.491379 -121.834613  King, Washington, US  9/29/21
# 607             US  47.491379 -121.834613  King, Washington, US  9/30/21
# 608             US  47.491379 -121.834613  King, Washington, US  10/1/21
#
#         cases new_date_format  daily_cases  Week  rate_of_change  rolling_avg
# 0         1.0      2020-02-01          0.0   1.0             NaN     0.000000
# 1         1.0      2020-02-02          0.0   1.0             0.0     0.000000
# 2         1.0      2020-02-03          0.0   1.0             0.0     0.000000
# 3         1.0      2020-02-04          0.0   1.0             0.0     0.000000
# 4         1.0      2020-02-05          0.0   1.0             0.0     0.000000
# ..        ...             ...          ...   ...             ...          ...
# 604  150197.0      2021-09-27       1547.0  44.0          1547.0   496.357143
# 605  150532.0      2021-09-28        335.0  44.0         -1212.0   499.000000
# 606  150923.0      2021-09-29        391.0  44.0            56.0   478.000000
# 607  151467.0      2021-09-30        544.0  44.0           153.0   482.214286
# 608  152022.0      2021-10-01        555.0  44.0            11.0   472.357143
#
# [609 rows x 19 columns]

# %%
fig, ax1 = plt.subplots(figsize=(20,10))
ax2 = ax1.twinx()
sns.set_style('ticks')
sns.lineplot(x="new_date_format", y="cases", data = kc_cases, ax=ax1, color='red', label='Total Number of Cases')
sns.lineplot(x="new_date_format", y="rolling_avg", data = kc_cases, ax=ax2, label='14-Day Rolling Average')
#sns.lineplot(x="new_date_format", y="average_number_of_cases", data=kc_cases_bi_weekly, ax=ax2, label="Bi-Weekly Average")
plt.axvspan(min(kc_mask_mandates['new_date_format']), max(kc_mask_mandates['new_date_format']), color='green', alpha=0.1, label='Mask Mandate Period (06/26/2020 - 08/15/2021)')
ax1.set_xlabel('Date', fontsize=13)
ax1.set_ylabel('Cumulative Cases', fontsize=13)
ax2.set_ylabel('Daily Cases', fontsize=13)
ax2.legend(loc=1, fontsize=13)
plt.legend(fontsize=13, loc=2)
plt.title("Confirmed COVID-19 Cases in King County, WA")
# Out:
# Text(0.5, 1.0, 'Confirmed COVID-19 Cases in King County, WA')

# %%
# rate of change of rolling average
kc_cases['rate_of_change'] = kc_cases['rolling_avg'].diff()

# %%
fig= plt.subplots(figsize=(10,5))
sns.set_style('ticks')
sns.lineplot(x="new_date_format", y="rate_of_change", data = kc_cases, color='red', label='Rate of Change')
plt.axvspan(min(kc_mask_mandates['new_date_format']), max(kc_mask_mandates['new_date_format']), color='green', alpha=0.1,label='Mask Mandate Period (06/26/2020 - 08/15/2021)')
plt.xlabel("Date", fontsize=13)
plt.ylabel("Rate of Change", fontsize=13)
plt.title("Rate of Change of 14 rolling day average COVID-19 Cases in King County,WA", fontsize=14)
plt.legend(fontsize=13,loc=2)

# %% [markdown]
# ### Change point analysis
#
# Here, we are going to find the changepoint in the cumulative sum of cases in King County. The changepoint will determine segments of this data, that have its own statisical significance.
# After finding these changepoints, we are going to see how the derivative function of the rate of growth of COVID-19 cases (the slope) differs amongst the segments.

# %%
#use ruptures library (should install)
import ruptures as rpt

# %%
cases = np.array(kc_cases['cases'])

# fit the model
fit = rpt.Pelt(model="rbf").fit(cases)
pred = fit.predict(pen = 10)

# get the index of predictions
pred = pred[:-1]
pred.insert(0, 0)
pred.insert(len(pred) +1, len(kc_cases))
print(pred)

# enumerate the changepoint onto the dataset
for i in range(pred[1]):
    kc_cases.at[i, 'changepoint'] = 1
#list_of_df = [kc_cases.iloc[]]

for i in range(2, len(pred)):
    for t in range(pred[i-1], pred[i]):
        kc_cases.at[t, 'changepoint'] = i



#rpt.display(cases, pred)
#plt.show
# Out:
# [0, 175, 295, 345, 445, 560, 609]

# %%
arr = np.arange(1, len(kc_cases), 1)
for i in arr:
    kc_cases.at[i-1, 'index'] = i

# %%
# We will find the regression line for each changepoint and plot against our total number of cases graph
c1 = kc_cases[kc_cases["changepoint"]==1]
c2 = kc_cases[kc_cases["changepoint"]==2]
c3 = kc_cases[kc_cases["changepoint"]==3]
c4 = kc_cases[kc_cases["changepoint"]==4]
c5 = kc_cases[kc_cases["changepoint"]==5]
c6 = kc_cases[kc_cases["changepoint"]==6]

x1 = c1['index']
x2 = c2['index']
x3 = c3['index']
x4 = c4['index']
x5 = c5['index']
x6 = c6['index']

y1 = c1['cases']
y2 = c2['cases']
y3 = c3['cases']
y4 = c4['cases']
y5 = c5['cases']
y6 = c6['cases']


m1,b1 = np.polyfit(x1, y1, 1)
m2,b2 = np.polyfit(x2, y2, 1)
m3,b3 = np.polyfit(x3, y3, 1)
m4,b4 = np.polyfit(x4, y4, 1)
m5,b5 = np.polyfit(x5, y5, 1)
m6,b6 = np.polyfit(x6, y6, 1)

c1['values'] = m1*x1 + b1
c2['values'] = m2*x2 + b2
c3['values'] = m3*x3 + b3
c4['values'] = m4*x4 + b4
c5['values'] = m5*x5 + b5
c6['values'] = m6*x6 + b6

# %%
fig = plt.figure(figsize=(15,10))
sns.lineplot(x="new_date_format", y = "cases", data=kc_cases, label="Total Number of Cases")
#rpt.display(cases, pred)
for x in indexing:
    plt.axvline(x, linestyle='dotted', c="black")
sns.lineplot(x="new_date_format", y="values", data=c1, label="Changepoint 1: Slope")
sns.lineplot(x="new_date_format", y="values", data=c2, label="Changepoint 1: Slope")
sns.lineplot(x="new_date_format", y="values", data=c3, label="Changepoint 1: Slope")
sns.lineplot(x="new_date_format", y="values", data=c4, label="Changepoint 1: Slope")
sns.lineplot(x="new_date_format", y="values", data=c5, label="Changepoint 1: Slope")
sns.lineplot(x="new_date_format", y="values", data=c6, label="Changepoint 1: Slope")
plt.axvspan(min(kc_mask_mandates['new_date_format']), max(kc_mask_mandates['new_date_format']), color='green', alpha=0.1, label='Mask Mandate Period')
plt.xlabel('Date', fontsize = 13)
plt.ylabel('Cumulative Cases', fontsize=13)
plt.title("Cumulative COVID-19 Confirmed Cases in King County, WA (Feb 2020 - Oct 2021)", fontsize=14)
plt.legend(fontsize=12)

# %% [markdown]
# Here, we can see various slopes within each changepoint. The slopes can interpret the rate at which COVID-19 rates grew over a specific amount of time. Before the masking mandate, we can see a slight increase in cases, however, this represents the start of COVID-19 in the area.

# %% [markdown]
# I would like to see a different or more efficient way to see the true effect of mask usage with respect to the behavior of COVID-19. In addition to analyzing the effect mask usage has, I would like to also see how vaccination played a role to prevent the spread. The extension for this project will be conducted in this Jupyter notebook: "insert here"
